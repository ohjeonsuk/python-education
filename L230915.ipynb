# %% [markdown]
# <a href="https://colab.research.google.com/github/ohjeonsuk/python-education/blob/main/L230915.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. DB : MySQL
#
# 6. Django : 블로그
#     - html / CSS
#     - MVT
#     - Model : 다대일 관계
#
# 7. 통계적 머신러닝
#     - sklearn
#     - 평가
#     - 분류
#     - 회귀
#     - 차원축소 / 군집
#     - 텍스트 처리
#
#
# 8. 딥러닝

# %% [markdown]
# # 레코드 삭제하기
#
#     delete from 테이블명 where 조건;
#
# # 칼럼 삭제하기
#     alter from 테이블명 drop 칼럼명;

# %% [markdown]
# # 필드 업데이트 하기
#     update 테이블이름 set 칼럼명=원하는 값 where 조건;
#
#     update delivery set delivery_time=NULL where (delivery_id=4);
#
#
# delivery : 테이블 이름
#
# delivery_time : 칼럼명

# %% [markdown]
# # CHAR 와 VARCHAR 차이

# %% [markdown]
# varchar(8) : 'test' -> 문자 4개
#
# char(8) : 'test' -> 문자 8개

# %% [markdown]
# # load data 명령어 사용시 null 값 생성
#
#     1. 데이터에 ' \N ' 넣어주기
#
#     2. 레코드의 마지막 값일 경우 ',' 없애기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 외래키에서 사용하는 동작
#
# FOREIGN KEY 제약 조건에 의해 참조되는 테이블에서 데이터의 수정이나 삭제가 발생하면, 참조하고 있는 테이블의 데이터도 같이 영향을 받습니다.
#
# 이때 참조하고 있는 테이블의 동작은 다음 키워드를 사용하여 FOREIGN KEY 제약 조건에서 미리 설정할 수 있습니다.
#
#
#
# 1. ON DELETE
#
# 2. ON UPDATE
#
#
#
# 참조되는 테이블의 값이 삭제될 경우의 동작은 ON DELETE 구문으로 설정할 수 있습니다.
#
# 또한, 참조되는 테이블의 값이 수정될 경우의 동작은 ON UPDATE 구문으로 설정할 수 있습니다.

# %% [markdown]
# ## ON DELETE 또는 ON UPDATE에서 사용할 수 있는 옵션
#
#
# 1. CASCADE : 참조되는 테이블에서 데이터를 삭제하거나 수정하면, 참조하는 테이블에서도 삭제와 수정이 같이 이루어집니다.
#
# 2. SET NULL : 참조되는 테이블에서 데이터를 삭제하거나 수정하면, 참조하는 테이블의 데이터는 NULL로 변경됩니다.
#
# 4. SET DEFAULT : 참조되는 테이블에서 데이터를 삭제하거나 수정하면, 참조하는 테이블의 데이터는 필드의 기본값으로 설정됩니다.
#
# 5. RESTRICT : 참조하는 테이블에 데이터가 남아 있으면, 참조되는 테이블의 데이터를 삭제하거나 수정할 수 없습니다.

# %%
# %%writefile Orders.csv
# 1,Paper,500,5
# 2,pen,10,2
# 3,Marker,120,3
# 4,Books,1000,1
# 5,Erasers,20,4
# Out:
# Writing Orders.csv

# %%
# %%writefile customers.csv
# 1,John,Doe,31,USA
# 2,Robert,Luna,22,USA
# 3,David,Robinson,22,UK
# 4,John,Reinhardt,35,UK
# 5,Betty,Doe,28,UAE
# Out:
# Writing customers.csv
