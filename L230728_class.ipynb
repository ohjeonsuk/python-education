# %% [markdown]
# <a href="https://colab.research.google.com/github/ohjeonsuk/python-education/blob/main/L230728_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html>
<body>

<h1>My First Heading</h1>

<p>My first paragraph.</p>

</body>
</html>

# %% [markdown]
# cpu 2.0 GHz IBM
#
# <device> cpu </device>
# <speed> 2.0 </speed>
# ...
#
# html ->  xml -> JSON

# %%
import json
def get_data(file_names):
    with open(file_names) as f:
        datas = json.load(f)
    #print(f)
    return(datas)

# %%
data = get_data('restroom.json')

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 11157

# %%
data[2]
# Out:
# {'PUBLFACLT_DIV_NM': '공중화장실',
#  'PBCTLT_PLC_NM': '호수빌딩',
#  'REFINE_ROADNM_ADDR': '경기도 고양시 일산동구 정발산로 23',
#  'REFINE_LOTNO_ADDR': '경기도 고양시 일산동구 정발산로 23 (장항동, 호수빌딩)',
#  'MALE_FEMALE_CMNUSE_TOILET_YN': 'N',
#  'MALE_WTRCLS_CNT': '13',
#  'MALE_UIL_CNT': '18',
#  'MALE_DSPSN_WTRCLS_CNT': '0',
#  'MALE_DSPSN_UIL_CNT': '0',
#  'MALE_KID_WTRCLS_CNT': '0',
#  'MALE_KID_UIL_CNT': '0',
#  'FEMALE_WTRCLS_CNT': '14',
#  'FEMALE_DSPSN_WTRCLS_CNT': '0',
#  'FEMALE_KID_WTRCLS_CNT': '0',
#  'MNGINST_NM': '일산동구청 환경녹지과',
#  'MNGINST_TELNO': '031-8075-6243',
#  'OPEN_TM_INFO': ':~:',
#  'INSTL_YM': '',
#  'REFINE_WGS84_LAT': '37.6567272061',
#  'REFINE_WGS84_LOGT': '126.7713048729',
#  'TOILET_POSESN_DIV': 'N',
#  'TOILET_INSTL_PLC_TYPE': 'N',
#  'PROC_CONT': 'N',
#  'EMBEL_INSTL_YN': 'N',
#  'EMBEL_INSTL_PLC': 'N',
#  'TOILET_YN': 'N',
#  'INSTL_YN': 'N',
#  'PLC_NM': 'N',
#  'RE_BUILD_YM': '',
#  'DATA_STD_DE': '2022-04-08'}

# %%
for i in data[39:45]:
    print(i['PBCTLT_PLC_NM'])
    if i['REFINE_WGS84_LAT']:
        print(float(i['REFINE_WGS84_LAT']))
        print(i['REFINE_WGS84_LOGT'])

# %%
import folium
def map_add(maps, data):
    for item in data:
        name = item['PBCTLT_PLC_NM']
        if item['REFINE_WGS84_LAT']:
            latitude = float(item['REFINE_WGS84_LAT'])
            longitude = float(item['REFINE_WGS84_LOGT'])
            folium.CircleMarker([latitude, longitude], radius=4, popup=name, color='red', fill_color='red').add_to(maps)
    return maps
def FoliumMap(data, save_file='result.html'):
    maps = folium.Map(location=[37.5602, 126.982], zoom_start=7)
    map_add(maps, data).save(save_file)

# %%
FoliumMap(data)

# %% [markdown]
# ![Class.drawio-2.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# 클래스와 이름 공간
#
# ---

# %%
class S1:
    a = 1

# %%
x = S1()

# %%
type(x)
# Out:
# __main__.S1

# %%
S1.a
# Out:
# 1

# %%
x.c =10

# %%
x.c
# Out:
# 10

# %%
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'a',
#  'c']

# %%
dir(S1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'a']

# %%
x.a
# Out:
# 1

# %%
x.a=10

# %%
S1.a
# Out:
# 1

# %%
x.a

# %%
S1.b = 2

# %%
x.b = 4

# %%
y = S1()

# %%
y.a
# Out:
# 1

# %%
y.b
# Out:
# 2

# %%
y.a = 100
y.b = 200

# %%
print(S1.a, S1.b, x.a, x.b, y.a, y.b)
# Out:
# 1 2 10 4 100 200

# %% [markdown]
# ##연산자 중복

# %%
class MyClass:
    def __add__(self, x):
        print(f'add {x} called')
        return x

# %%
a = MyClass()

# %%
a + 3
# Out:
# add 3 called
# 3

# %% [markdown]
# 클래스 정의와 인스턴스 객체의 생성
#
# - 함수를 호출 하듯이 클래스를 호출하여 인스턴스 객체를 생성한다.

# %%
class Simple:
    pass

# %%
s1 = Simple()

# %%
s1

# %%
s2 = Simple()

# %%
s2

# %%
Simple.__bases__
# Out:
# (object,)

# %%
dir(Simple)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Simple(list):
    pass

# %%
Simple.__bases__
# Out:
# (list,)

# %%
dir(Simple)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
s1.stack = []

# %%
s1.stack.append(1)

# %%
s1.stack
# Out:
# [1]

# %%
s1.stack.append(2)

# %%
type(s1)
# Out:
# __main__.Simple

# %%
class Simple2(list):
    pass

# %%
s3 = Simple2()

# %%
type(s3)
# Out:
# __main__.Simple2

# %%
type(Simple2)
# Out:
# type

# %%
type(s1.stack)
# Out:
# list

# %%
s1.stack
# Out:
# [1, 2]

# %%
dir(s2)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class MyClass:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
s1 = Simple()

# %%
mc_1 = MyClass('아무개', '아무살')

# %%
mc1 = MyClass()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-32a8e013ce28> in <cell line: 1>()
# ----> 1 mc1 = MyClass()
#
# TypeError: MyClass.__init__() missing 2 required positional arguments: 'name' and 'age'

# %% [markdown]
# ![class-페이지-2.drawio.png](data:image/png;base64,...)

# %%
mc_1.

# %% [markdown]
# ## 5.클래스
#
# <파이썬3 바이블, 이강성>
#
# - 클래스는 새로운 이름 공간을 지원하는 단위이다.
#
# - 이 이름 공간에는 함수와 변수가 포함될 수 있다.
#
# - 클래스를 정의하는 것은 새로운 자료형을 하나 만드는 것이다.
#
# - 인스턴스는 이 자료형의 객체를 생성하는 것이다.
#
# - 클래스 인스턴스 : 클래스를 호출하여 생성된 객체이다.
#
# - 클래스 인스턴스는 클래스의 실제 객체이다.
#
# - 클래스 인스턴스 객체 : 클래스 인스턴스와 같은 의미이다. 인스턴스 객체라고 부르기도 한다.
#
# - 멤버 : 클래스 혹은 클래스 인스턴스 공간에 정의된 변수이다.
#
# - 메서드 : 클래스 공간에 정의된 함수이다.
#
# - 속성(Attribute) : 멤버와 메서드 전체를 가리킨다.

# %%
mc2 = MyClass('tom', 21)

# %%
mc2.age
# Out:
# 21

# %%
mc2.name
# Out:
# 'tom'

# %%
mc_1.age
# Out:
# '아무살'

# %%
mc_1.name
# Out:
# '아무개'

# %%
class MyClass:
    def __init__(self):
        self.age = 21
        self.name = 'Guido'

# %%
mc3 = MyClass()

# %%
mc3.age
# Out:
# 21

# %%
mc3.name
# Out:
# 'Guido'

# %%
class MyClass:
    def __init__(self, age=21, name='Guido'):
        self.age = age
        self.name = name

# %%
mc4 = MyClass()
mc5 = MyClass(23)
mc6 = MyClass(23, 'python')

# %%
mc5.age
# Out:
# 23

# %%
mc5.name
# Out:
# 'Guido'

# %%
mc6.age, mc6.name
# Out:
# (23, 'python')

# %%
class MyClass:
    def __init__(self, phone, age=21, name='Guido'):
        self.phone = phone
        self.age = age
        self.name = name
    def print_attr(self, number):
        self.number = number
        print(self.phone)
        self.phone = self.number
        return self.phone

# %%
mc7 = MyClass('마구눌러')

# %%
mc7.print_attr()
# Out:
# 마구눌러

# %%
mc7.print_attr()
# Out:
# 마구눌러

# %%
mc8 = MyClass('마구눌러')

# %%
mc8.print_attr('마구눌러')
# Out:
# 010 5678 4568
# '마구눌러'

# %% [markdown]
# #상속
#
# - 클래스는 다른 클래스를 상속 받을 수 있다. (모든 파이썬 클래스는 object 클래스를 기반(Base) 클래스로 한다.)

# %%
class A:
    def f(self):
        print('base')
class B(A):
    pass

# %%
b = B()

# %%
b.f()
# Out:
# base

# %%
B.__bases__
# Out:
# (__main__.A,)

# %%
dir(B)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'f']

# %%
dir(b)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'f']

# %% [markdown]
# #메서드의 정의와 호출
# - 메서드를 정의하는 방법은 일반 함수를 정의하는 것과 동일하다.
#
# - 첫번째 인수는 해당 클래스의 인스턴스 객체(self) 이어야 한다.

# %%
class MyClass:
    def set(self, v):
        self.value = v
    def get(self):
        return self.value
    def temp(self):
        self.value2 = self.get() #get()
        print(self.value2)

# %% [markdown]
# 'egg'

# %%
mc9 = MyClass()
mc9.set('egg')
mc9.temp()
# Out:
# egg

# %%
MyClass.set(mc9, 100) #unbound method 호출

# %%
mc9.set
# Out:
# <bound method MyClass.set of <__main__.MyClass object at 0x7ecdd1fbc3d0>>

# %%
MyClass.get(mc9)
# Out:
# 100

# %%
class MyClass2:
    def set(self, v):
        self.value = v
    def get(self):
        return self.value
    def incr(self):
        self.value += 1
        return self.get()

# %%
10, 11
# Out:
# (10, 11)

# %%
mc3 = MyClass2()
mc3.set(10)
mc3.incr()
# Out:
# 11

# %% [markdown]
# #생성자와 소멸자

# %% [markdown]
# 생성자 함수의 이름 : __ init __
#
# 소멸자 함수의 이름 : __ del __ (인스턴스 객체를 제거)
#
# __ init __ 메서드는 인스턴스 객체가 생성되고 나서 자동으로 호출 된다.

# %%
from time import time, ctime, sleep

# %%
class Life:
    def __init__(self):
        self.birth = ctime()
        print('Birthday', self.birth)
    def __del__(self):
        print('Deathday', ctime())

# %%
life_io= Life()
# Out:
# Birthday Fri Jul 28 07:08:12 2023

# %%
del(life_io) # del() 함수에 __del__(self) 가 대응 된다.
# Out:
# Deathday Fri Jul 28 07:09:14 2023

# %%
life_io
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9f62d7fe1d80> in <cell line: 1>()
# ----> 1 life_io
#
# NameError: name 'life_io' is not defined

# %% [markdown]
# # 클래스 멤버와 인스턴스 멤버
#
# - 클래스 멤버는 메서드 바깥에 정의한다.
#
# - 인스턴스 멤버는 메서드 내부에서 self 를 이용하여 정의한다.

# %%
class Var:
    c_mem = 100 # 클래스 멤버
    def f(self):
        self.i_mem = 200 # 인스턴스 멤버
    def g(self):
        return self.i_mem, self.c_mem

# %%
Var.c_mem
# Out:
# 100

# %%
v1 = Var()
v2 = Var()

# %%
v1.c_mem
# Out:
# 100

# %%
v2.c_mem
# Out:
# 100

# %%
v1.c_mem=50

# %% [markdown]
# 메서드 setdata : first, second 를 인스턴스 변수로 만들어주는 메서드
#
# add : 합
#
# mul : 곱하기
#
# sub : 빼기
#
# div : 나누기
#
# 클래스 작성해 주세요.
#
# 생성자 : first, second 입력 받게 함
#
# 클래스 이름 : FourCal

# %%
class FourCal:
    def __init__(self, first, second):
        self.setdata(first, second)
    def setdata(self, first, second):
        self.first = first
        self.second = second
    def add(self):
        return self.first + self.second
    def mul(self):
        return self.first * self.second
    def sub(self):
        return self.first - self.second
    def div(self):
        return self.first / self.second

# %%
fc = FourCal(10, 2)
print(fc.add())
print(fc.sub())
print(fc.mul())
fc.div()
# Out:
# 12
# 8
# 20
# 5.0

# %% [markdown]
# 나누기에서 0으로 나눌때, error 아니고, 결과값을 0으로 해주는
#
# 클래스 SafeFourCal 를 만들어 주세요.

# %%
class SafeFourCal(FourCal):
    def div(self):
        if self.second == 0:
            return 0
        return self.first/self.second
