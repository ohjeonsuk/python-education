# %% [markdown]
# <a href="https://colab.research.google.com/github/ohjeonsuk/python-education/blob/main/_L230919.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. DB : MySQL
#
# 6. Django : 블로그
#     - html / CSS
#     - MVT
#
# 7. 통계적 머신러닝
#     - sklearn
#     - 평가
#     - 분류
#     - 회귀
#     - 차원축소 / 군집
#     - 텍스트 처리
#
#
# 8. 딥러닝

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1>
# 글자크기
# </h1>
#
# <h4>
# 글자크기
# </h4>

# %%
https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&rlz=1C5CHFA_enKR1063KR1063&oq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&aqs=chrome..69i57j69i59l3j69i61j69i65l3.716509815j0j15&sourceid=chrome&ie=UTF-8
